# %% [markdown]
# ## Nome: Felipe Silva Loschi
# ## Matrícula: 601

# %% [markdown]
# ---

# %% [markdown]
# PARTE PRÁTICA

# %% [markdown]
# # Atividade – Análise de Erros em Medições Experimentais
#
# Questão 1.
#
# Um professor de Engenharia Química, realizou um experimento com seus alunos
# à respeito do calor específico da água. O experimento consiste em aquecer uma
# massa de água com um calorímetro e com isso medir a variação da temperatura, assim podendo calcular os
# novos valores do calor específico. Porém, os resultados obtidos foram diferentes do
# valor exato do calor específico da água. Devido à isso o professor
# passou esses dados em uma tabela para você fazer um estudo sobre erros e métodos numéricos.
#
# Importante citar que o valor do calor específico da água é de aproximadamente 4,186 kJ/(kg·K)
#
#
# Os resultados dos alunos estão na tabela abaixo:
#
# | Alunos               | Valor Medido (KJ) |
# |-----------------------------------|---------------------|
# | Karina             | 4.18           |
# | Pedro        | 4.17               |
# | Lívia               |     4.178           |
# | Lucas      | 4.189               |
# | Paulo            | 4.201             |
# | Soned       | 4.187             |
#
#
# Seu objetivo é analisar esses dados e calcular diferentes métricas de erro,
# utilizando Python e bibliotecas como **pandas**, **numpy** e **matplotlib**.
#
# ---

# %%
from IPython.display import display, Markdown
# Importando bibliotecas

#Analise de dados
import pandas as pd
import numpy as np

#Plotar gráficos
import matplotlib.pyplot as plt

# %%
#Tabela de dados
tabela = {
    "Alunos": [
        "Karina", "Pedro", "Livia",
        "Lucas", "Paulo",
        "Soned"
    ],
    "Valor Medido (K*J)": [4.18, 4.17, 4.178, 4.189, 4.201, 4.187]
}

dados = pd.DataFrame(tabela)
display(dados)
# Out:
#    Alunos  Valor Medido (K*J)
# 0  Karina               4.180
# 1   Pedro               4.170
# 2   Livia               4.178
# 3   Lucas               4.189
# 4   Paulo               4.201
# 5   Soned               4.187

# %% [markdown]
# ### Parte 1 - Erro Absoluto, Erro Relativo e Erro Percentual

# %%
# Ordenando igual a atividade passada
df_ordenado = dados.sort_values(by='Valor Medido (K*J)', ascending=True).reset_index(drop=True)

# Valor teórico
valor_teorico = 4.186

# Função para calcular erro absoluto
def erro_absoluto(valor_teorico, valor_medido):
    return abs(valor_teorico - valor_medido)

# Função para calcular erro relativo (corrigido: dividir pelo teórico)
def erro_relativo(erro_abs, valor_teorico):
    return erro_abs / abs(valor_teorico)

# Função para calcular erro percentual
def erro_percentual(erro_rel):
    return erro_rel * 100


for i in range(len(df_ordenado)):
    nome = df_ordenado.loc[i, "Alunos"]
    valor_medido = df_ordenado.loc[i, "Valor Medido (K*J)"]

    ea = erro_absoluto(valor_teorico, valor_medido)
    er = erro_relativo(ea, valor_teorico)
    ep = erro_percentual(er)

    print(f"Aluno {nome}")
    print(f"Erro absoluto: {ea}")
    print(f"Erro relativo: {er}")
    print(f"Erro percentual: {ep}%\n")
# Out:
# Aluno Pedro
# Erro absoluto: 0.016000000000000014
# Erro relativo: 0.0038222646918299125
# Erro percentual: 0.38222646918299125%
#
# Aluno Livia
# Erro absoluto: 0.008000000000000007
# Erro relativo: 0.0019111323459149562
# Erro percentual: 0.19111323459149562%
#
# Aluno Karina
# Erro absoluto: 0.006000000000000227
# Erro relativo: 0.0014333492594362702
# Erro percentual: 0.143334925943627%
#
# Aluno Soned
# Erro absoluto: 0.001000000000000334
# Erro relativo: 0.0002388915432394491
# Erro percentual: 0.023889154323944912%
#
# Aluno Lucas
# Erro absoluto: 0.0030000000000001137
# Erro relativo: 0.0007166746297181351
# Erro percentual: 0.0716674629718135%
#
# Aluno Paulo
# Erro absoluto: 0.01499999999999968
# Erro relativo: 0.0035833731485904637
# Erro percentual: 0.35833731485904635%

# %% [markdown]
# Calcule o Erro Absoluto, o Erro Relativo e o Erro Percentual dos valores medidos.

# %% [markdown]
# **Formulário para cálculo de erros do calor específico**
#
# - Erro Absoluto:
# $$E_a = |V_t - V_m|$$
#
# - Erro Relativo:
# $$E_r = \frac{E_a}{|V_m|}$$
#
# - Erro Percentual:
# $$E_p = E_r \times 100\%$$
#
# Onde:
# - $V_t$ = valor teórico do calor específico (4,186 kJ/(kg·K))
# - $V_m$ = valor medido pelo aluno

# %% [markdown]
# ### Parte 2 - Arredondamento e Truncamento

# %% [markdown]
# Um engenheiro de produção está desenvolvendo um sistema para controle de corte de peças metálicas.
# O equipamento mede o comprimento das peças, mas as medições apresentam várias casas decimais,
# sendo necessário arredondar os valores para atender às especificações técnicas da indústria.
# Esse engenheiro, a fim de deixar mais didático as suas medições, decidiu propor para você uma série de tarefas,
# e você deverá auxiliá-lo nessa importante atividade.
#
# As medidas coletadas pelo engenheiro estão anotadas na tabela:

# %% [markdown]
# | Peça              | Comprimento medido (cm) |
# |-----------------------------------|---------------------|
# | P1             | 12.3456           |
# | P2        |           9.8765     |
# | P3               |     15.5555          |
# | P4      | 7.4999            |
# | P5            | 10.0501            |
#
# As terefas pedidas por eles são:

# %% [markdown]
# ### 1 - Fazer um DataFrame para organização visual dos dados

# %%
#Tabela de dados
tabela = {
    "Peça": [
        "P1", "P2", "P3",
        "P4", "P5"
    ],
    "Comprimento Medido (cm)": [12.3456, 9.8765, 15.5555, 7.4999, 10.0501]
}

dados = pd.DataFrame(tabela)
display(dados)

# Ordenando igual a atividade passada
df_ordenado = dados.sort_values(by='Comprimento Medido (cm)', ascending=True).reset_index(drop=True)

print("\nTabela Ordenada:")
display(df_ordenado)
# Out:
#   Peça  Comprimento Medido (cm)
# 0   P1                  12.3456
# 1   P2                   9.8765
# 2   P3                  15.5555
# 3   P4                   7.4999
# 4   P5                  10.0501
# Tabela Ordenada:
#   Peça  Comprimento Medido (cm)
# 0   P4                   7.4999
# 1   P2                   9.8765
# 2   P5                  10.0501
# 3   P1                  12.3456
# 4   P3                  15.5555

# %% [markdown]
# ### 2 - Preciso que arredonde todos os valores para 2 casas decimais, para me ajudar nos cálculos

# %%
#Copiando o dataframe ordenado para um novo data frame
df_ordenado_arredondado = df_ordenado.copy()
#Arredondando as casas desse novo dataframe e mostrando
df_ordenado_arredondado["Comprimento Medido (cm)"] = df_ordenado_arredondado["Comprimento Medido (cm)"].round(2)
print("Tabela com os valores arredondados:")
display(df_ordenado_arredondado)
# Out:
# Tabela com os valores arredondados:
#   Peça  Comprimento Medido (cm)
# 0   P4                     7.50
# 1   P2                     9.88
# 2   P5                    10.05
# 3   P1                    12.35
# 4   P3                    15.56

# %% [markdown]
# ### 3 - Após isso, quero que trunque os valores para 1 casa decimal

# %%
#Copiando para um novo df e fazendo o truncamento
df_ordenado_truncado = df_ordenado_arredondado.copy()
df_ordenado_truncado["Comprimento Medido (cm)"] = np.trunc(df_ordenado_truncado["Comprimento Medido (cm)"] * 10) / 10
#Mostrando
print("Tabela com os valores truncados:")
display(df_ordenado_truncado)
# Out:
# Tabela com os valores truncados:
#   Peça  Comprimento Medido (cm)
# 0   P4                      7.5
# 1   P2                      9.8
# 2   P5                     10.0
# 3   P1                     12.3
# 4   P3                     15.5

# %% [markdown]
# ### 4 - Mostre para mim depois, o valor inteiro mais próximo

# %%
#Copiando para um novo df e arredondando
df_ordenado_inteiro = df_ordenado_truncado.copy()
df_ordenado_inteiro["Comprimento Medido (cm)"] = df_ordenado_inteiro["Comprimento Medido (cm)"].round(0).astype(int)
#Mostrando
print("Tabela com os valores inteiros mais próximos:")
display(df_ordenado_inteiro)
# Out:
# Tabela com os valores inteiros mais próximos:
#   Peça  Comprimento Medido (cm)
# 0   P4                        8
# 1   P2                       10
# 2   P5                       10
# 3   P1                       12
# 4   P3                       16

# %% [markdown]
# ### 5 - E me mostrar os resultados dentro de uma tabela

# %%
#Mostrando
valores = df_ordenado.iloc[:,1]
valores_arredondados = df_ordenado_arredondado.iloc[:,1]
valores_truncados = df_ordenado_truncado.iloc[:,1]
valores_inteiros = df_ordenado_inteiro.iloc[:,1]
tabela = {
    "Valores" : valores,
    "Valores Arredondados" : valores_arredondados,
    "Valores Truncados" : valores_truncados,
    "Valores Inteiros" : valores_inteiros
}
df_resultados = pd.DataFrame(tabela)
display(df_resultados)
# Out:
#    Valores  Valores Arredondados  Valores Truncados  Valores Inteiros
# 0   7.4999                  7.50                7.5                 8
# 1   9.8765                  9.88                9.8                10
# 2  10.0501                 10.05               10.0                10
# 3  12.3456                 12.35               12.3                12
# 4  15.5555                 15.56               15.5                16

# %% [markdown]
# <span style="font-size:90%">
#
# **Guia Rápido: Arredondamento e Truncamento**
#
# - Arredondar para n casas decimais: `dados["Comprimento Medido (cm)"].round(0)`
# - Truncar para n casas decimais: `np.trunc(dados["Comprimento Medido (cm)"] * 10) / 10`
# - Arredondar para inteiro mais próximo: `dados["Comprimento Medido (cm)"].round(0).astype(int)`
#
# </span>

# %% [markdown]
# ## Parte Teórica

# %% [markdown]
# **Questão 1.**
#
# Julgue as afirmativas abaixo como V (Verdadeiro) ou F (Falso) e justifique as que forem Falsas.

# %% [markdown]
# 1. É possível representar qualquer grandeza física em termos das unidades básicas da Física. (V)
#
# 2. O instrumento de medida escolhido para medir uma grandeza deve ser coerente com aquilo que se deseja medir. (V)
#
# 3. A incerteza não precisa ser levada em consideração e não é necessária para compararmos os dados. (F)
#
# 4. O erro relativo é calculado dividindo o erro absoluto pelo valor teórico. (F)
#
# 5. O número de algoritmos significativos de uma grandeza é determinado pela sua incerteza. (V)

# %% [markdown]
# **Questão 2.**
#
# Quando você faz a medição de alguma grandeza, com um instrumento de medição qualquer, em qual conjunto cai a medida que você
# obteve?
#
# Conjunto dos números Naturais, Inteiros, Racionais, Irracionais, Reais ou Complexos? Justifique sua resposta
#
# Reais, pois quando realizamos uma medida, o valor medido pode ter uma parte real e uma parte decimal e também pode ser um valor fracionário em que há muitas casas, representando os irracionais. Nesse sentido, o conjunto que abrange todas as necessidades é o conjunto dos reais. Não pode ser os complexos pois as medidas não assumem valores complexos, mesmo se negativas.

# %% [markdown]
# **Questão 3.**
#
# Suponhamos que deseje medir o tamanho de um besouro.
# Foi decidido também, o que caracteriza o tamanho do besouro, qual das alternativas abaixo melhor caracteriza a medida
# do tamanho do besouro?

# %% [markdown]
# a) Entre 0 e 1 cm
#
# b) Entre 1 e 2 cm
#
# c) Entre 1,5 e 1,6
#
# d) Entre 1,54 e 1,56
#
# e) Entre 1,546 e 1,547
#
# Resposta: Letra C

# %% [markdown]
# ![Besouro.png](data:image/png;base64,...)

# %% [markdown]
# **Questão 4.**
#
#
# Seja o número a = 4876 representado por a
# ′ = 4875,8 e seja o número 𝑦 = 12,7 representado por
# 𝑦
# ′ = 12,6.
#
# Pode-se dizer que ambos os números estão representados com a mesma precisão?
#
# Resposta: Não, pois "a" tem um maior número de algarismos significativos, fazendo dele mais preciso que "y"
